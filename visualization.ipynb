# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style='darkgrid', context='talk', palette='colorblind')

# %% [markdown]
# ## Keywords

# %%
df = pd.read_csv('paperlist.tsv', sep='\t')
df.drop_duplicates(inplace=True) # sometimes data is crawled twice by the code, so we find and delete duplicates
df.set_index('paper_id', inplace=True)
print('# papers:', len(df))
df.head()
# Out:
# # papers: 3262
#                                                          title  \
# paper_id
# RAW9tCdVxLj  Zero-CL: Instance and Feature decorrelation fo...
# Da3ZcbjRWy   Self-Supervised Representation Learning via La...
# Az-7gJc6lpr         Relational Learning with Variational Bayes
# givsRXsOt9r  Spherical Message Passing for 3D Molecular Graphs
# biyvmQe5jM                     How to decay your learning rate
#
#                                                     link  \
# paper_id
# RAW9tCdVxLj  https://openreview.net/forum?id=RAW9tCdVxLj
# Da3ZcbjRWy    https://openreview.net/forum?id=Da3ZcbjRWy
# Az-7gJc6lpr  https://openreview.net/forum?id=Az-7gJc6lpr
# givsRXsOt9r  https://openreview.net/forum?id=givsRXsOt9r
# biyvmQe5jM    https://openreview.net/forum?id=biyvmQe5jM
#
#                                                       keywords  \
# paper_id
# RAW9tCdVxLj  Self supervised learning, representation learning
# Da3ZcbjRWy   Self-supervised learning, representation learn...
# Az-7gJc6lpr  Relational learning, psychology, unsupervised ...
# givsRXsOt9r                                                NaN
# biyvmQe5jM    learning rates, hyperparameter tuning, schedules
#
#                                                       abstract
# paper_id
# RAW9tCdVxLj  For self-supervised contrastive learning, mode...
# Da3ZcbjRWy   Self-supervised learning (SSL) of graph neural...
# Az-7gJc6lpr  In psychology, relational learning refers to t...
# givsRXsOt9r  We consider representation learning of 3D mole...
# biyvmQe5jM   Complex learning rate schedules have become an...

# %%
counts = pd.Series(
    ', '.join(df['keywords'].dropna()).lower().replace('-', ' ').replace('networks', 'network').split(',')
).str.strip().value_counts().sort_values(ascending=True)
counts.iloc[-50:].plot.barh(figsize=(8, 12), title='ICLR 2021 Submission Top 50 Keywords')
plt.savefig('asset/keywords.png', dpi=300, bbox_inches='tight')

# %%
from imageio import imread
from wordcloud import WordCloud

wc = WordCloud(background_color="white", max_words=300, max_font_size=64, 
               width=1280, height=640, random_state=0)
wc.generate_from_frequencies(counts.to_dict())
fig = plt.figure(figsize=(16, 8))
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.savefig('asset/wordcloud.png', dpi=300, bbox_inches='tight')

# %%
from imageio import imread
from wordcloud import WordCloud

logo = imread('asset/ICLR-mask.png')
wc = WordCloud(background_color="white", max_words=300, max_font_size=64, 
               width=1280, height=640, random_state=0, mask=logo)
wc.generate_from_frequencies(counts.to_dict())
fig = plt.figure(figsize=(16, 8))
plt.imshow(logo)
plt.imshow(wc, interpolation="bilinear", alpha=.75)
plt.axis("off")
plt.savefig('asset/logo_wordcloud.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## Rating Distributions

# %%
ratings = pd.read_csv('ratings.tsv', sep='\t', index_col=0)
print(ratings.iloc[:, :-1].stack().mean())
ratings.head()
# Out:
# 4.9417168197656
#                0    1    2    3    4   5   6 decision
# paper_id
# RAW9tCdVxLj  8.0  6.0  6.0  5.0  NaN NaN NaN  Unknown
# Da3ZcbjRWy   5.0  5.0  6.0  5.0  NaN NaN NaN  Unknown
# Az-7gJc6lpr  6.0  6.0  5.0  6.0  5.0 NaN NaN  Unknown
# givsRXsOt9r  5.0  6.0  6.0  NaN  NaN NaN NaN  Unknown
# biyvmQe5jM   6.0  3.0  3.0  6.0  NaN NaN NaN  Unknown

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 6), gridspec_kw={'width_ratios': [1, 2]})
ratings.iloc[:, :-1].stack().value_counts().sort_index().plot.bar(
    ax=axes[0], title='ICLR 2021 Overall Ratings', xlabel='Rating', ylabel='Frequency')
ratings.iloc[:, :-1].mean(axis=1).mul(4).round().div(4).round(1).value_counts().sort_index().plot.bar(
    ax=axes[1], title='ICLR 2021 Ratings Averaged By Paper', xlabel='Avg Rating', ylabel='# Papers')
plt.tight_layout()
plt.savefig('asset/ratings_dist.png', dpi=300, bbox_inches='tight')

# %%
data = {}
for keywords, rating in zip(df.keywords, ratings.iloc[:, :-1].mean(axis=1)):
    if (isinstance(keywords, float) and np.isnan(keywords)) or np.isnan(rating):
        continue
    for keyword in keywords.lower().replace('-', ' ').replace('networks', 'network').split(','):
        data.setdefault(keyword.strip(), []).append(rating)

t = pd.DataFrame({
    'Frequency': [min(len(v), 50) for v in data.values()], # clip to 50
    'AverageRating': [np.mean(v) for v in data.values()],
    'Keyword': list(data.keys())
}).query('Frequency>9')
t.plot.scatter(x='Frequency', y='AverageRating', figsize=(16, 12))

for i in range(len(t)):
     plt.text(t.Frequency.iloc[i], t.AverageRating.iloc[i], t.Keyword.iloc[i], 
              horizontalalignment='left', 
              size='small', color='black', alpha=0.6)

plt.tight_layout()
plt.savefig('asset/keyword_ratings.png', dpi=300, bbox_inches='tight')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# ## Top 50 Papers

# %%
comb_df = pd.DataFrame({
    'AvgRating': ratings.iloc[:, :-1].mean(axis=1).round(2),
    'Title': '[' + df['title'] + ']' + '(' + df['link'] + ')',
    'Ratings': ratings.iloc[:, :-1].apply(lambda x: ', '.join(x.dropna().astype(int).astype(str).values), axis=1),
    'Decision': ratings.iloc[:, -1],
})

comb_df = comb_df.sort_values('AvgRating', ascending=False).reset_index(drop=True)
comb_df.index += 1
comb_df.index.name = 'Rank'
comb_df.head(50)
# Out:
#       AvgRating                                              Title  \
# Rank
# 1          8.00  [Assessing Generalization of SGD via Disagreem...
# 2          8.00  [Minibatch vs Local SGD with Shuffling: Tight ...
# 3          8.00  [Towards a Unified View of Parameter-Efficient...
# 4          8.00  [MIDI-DDSP: Detailed Control of Musical Perfor...
# 5          8.00  [Efficiently Modeling Long Sequences with Stru...
# 6          8.00  [Contrastive Label Disambiguation for Partial ...
# 7          8.00  [Score-Based Generative Modeling with Critical...
# 8          8.00  [EntQA: Entity Linking as Question Answering](...
# 9          8.00  [Possibility Before Utility: Learning And Usin...
# 10         8.00  [Sampling with Mirrored Stein Operators](https...
# 11         8.00  [Towards Deployment-Efficient Reinforcement Le...
# 12         8.00  [A General Analysis of Example-Selection for S...
# 13         8.00  [Iterative Refinement Graph Neural Network for...
# 14         8.00  [What Happens after SGD Reaches Zero Loss? --A...
# 15         8.00  [Finetuned Language Models are Zero-Shot Learn...
# 16         8.00  [Self-Supervision Enhanced Feature Selection w...
# 17         8.00  [Neural Deep Equilibrium Solvers](https://open...
# 18         8.00  [Emergent Communication at Scale](https://open...
# 19         8.00  [Bootstrapped Meta-Learning](https://openrevie...
# 20         8.00  [TAPEX: Table Pre-training via Learning a Neur...
# 21         8.00  [RISP: Rendering-Invariant State Predictor wit...
# 22         8.00  [TAMP-S2GCNets: Coupling Time-Aware Multipersi...
# 23         8.00  [Natural Language Descriptions of Deep Feature...
# 24         8.00  [MT3: Multi-Task Multitrack Music Transcriptio...
# 25         8.00  [A New Perspective on "How Graph Neural Networ...
# 26         8.00  [The Hidden Convex Optimization Landscape of R...
# 27         8.00  [On the Optimal Memorization Power of ReLU Neu...
# 28         8.00  [Reinforcement Learning under a Multi-agent Pr...
# 29         8.00  [Comparing Distributions by Measuring Differen...
# 30         7.67  [GNN-LM: Language Modeling based on Global Con...
# 31         7.67  [Diffusion-Based Voice Conversion with Fast Ma...
# 32         7.60  [Analytic-DPM: an Analytic Estimate of the Opt...
# 33         7.50  [Deconstructing the Inductive Biases of Hamilt...
# 34         7.50  [AdaRL: What, Where, and How to Adapt in Trans...
# 35         7.50  [RotoGrad: Gradient Homogenization in Multitas...
# 36         7.50  [Tackling the Generative Learning Trilemma wit...
# 37         7.50  [BEiT: BERT Pre-Training of Image Transformers...
# 38         7.50  [StyleAlign: Analysis and Applications of Alig...
# 39         7.50  [When Can We Learn General-Sum Markov Games wi...
# 40         7.50  [Exploring the Limits of Large Scale Pre-train...
# 41         7.50  [Perceiver IO: A General Architecture for Stru...
# 42         7.50  [Data-Efficient Graph Grammar Learning for Mol...
# 43         7.50  [Scalable Sampling for Nonsymmetric Determinan...
# 44         7.50  [Coordination Among Neural Modules Through a S...
# 45         7.50  [StyleNeRF: A Style-based 3D Aware Generator f...
# 46         7.50  [Learnability of convolutional neural networks...
# 47         7.50  [Scaling Laws for Neural Machine Translation](...
# 48         7.50  [Meta Discovery: Learning to Discover Novel Cl...
# 49         7.50  [Strength of Minibatch Noise in SGD](https://o...
# 50         7.50  [Approximation and Learning with Deep Convolut...
#
#             Ratings Decision
# Rank
# 1        8, 8, 8, 8  Unknown
# 2           8, 8, 8  Unknown
# 3          10, 8, 6  Unknown
# 4           8, 8, 8  Unknown
# 5           8, 8, 8  Unknown
# 6           8, 8, 8  Unknown
# 7       6, 8, 10, 8  Unknown
# 8           8, 8, 8  Unknown
# 9        8, 8, 8, 8  Unknown
# 10      8, 6, 10, 8  Unknown
# 11       8, 8, 8, 8  Unknown
# 12       8, 8, 8, 8  Unknown
# 13          8, 8, 8  Unknown
# 14      8, 6, 8, 10  Unknown
# 15       8, 8, 8, 8  Unknown
# 16          8, 8, 8  Unknown
# 17          8, 8, 8  Unknown
# 18       8, 8, 8, 8  Unknown
# 19       8, 8, 8, 8  Unknown
# 20          8, 8, 8  Unknown
# 21          8, 8, 8  Unknown
# 22             8, 8  Unknown
# 23          8, 8, 8  Unknown
# 24       8, 8, 8, 8  Unknown
# 25       8, 8, 8, 8  Unknown
# 26       8, 8, 8, 8  Unknown
# 27          8, 8, 8  Unknown
# 28          8, 8, 8  Unknown
# 29          8, 8, 8  Unknown
# 30         8, 10, 5  Unknown
# 31         5, 8, 10  Unknown
# 32    8, 8, 8, 6, 8  Unknown
# 33       6, 8, 8, 8  Unknown
# 34       8, 8, 6, 8  Unknown
# 35       8, 8, 6, 8  Unknown
# 36       8, 8, 6, 8  Unknown
# 37       8, 8, 8, 6  Unknown
# 38       8, 8, 6, 8  Unknown
# 39       6, 8, 8, 8  Unknown
# 40       8, 6, 8, 8  Unknown
# 41       8, 6, 8, 8  Unknown
# 42       8, 8, 6, 8  Unknown
# 43       8, 8, 6, 8  Unknown
# 44      6, 6, 8, 10  Unknown
# 45      10, 6, 6, 8  Unknown
# 46       6, 8, 8, 8  Unknown
# 47      8, 6, 10, 6  Unknown
# 48       6, 8, 8, 8  Unknown
# 49       6, 8, 8, 8  Unknown
# 50       8, 8, 6, 8  Unknown

# %%
with open('ranked_papers.md', 'w', encoding='utf8') as f:
    comb_df.to_markdown(f)
